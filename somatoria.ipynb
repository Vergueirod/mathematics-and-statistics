# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n: int = 5
for i in range(1, n+1):
        print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
n: int = 3
for i in range(1, n+1):
        print(f'({i} + 4)²')
# Out:
# ({i} + 4)²
# ({i} + 4)²
# ({i} + 4)²
